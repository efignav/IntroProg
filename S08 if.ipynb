# %% [markdown]
# ### OPERADORES RELACIONALES (O DE COMPARACION): ***==, !=, >, <***
# # DATOS BOOLEANOS: False (falso), True (verdadero)

# %%
nota = 13

print("nota:", nota == 13)

print("nota:", nota != 13)

print("nota:", nota > 13)

print("nota:", nota >= 13)

# %%
color = 'celeste'
numero = 15

print("color: ", color)
print("numero:", numero)
print()

# %%
# expresiones logicas simples
print("¿variable color == 'verde'?   ", color == 'verde')
print("¿variable color == 'celeste'? ", color == 'celeste')
print()

print("¿variable numero == 15?", numero == 15)
print("¿variable numero == 12?", numero == 12)
print()
# Out:
# ¿variable color == 'verde'?    False
# ¿variable color == 'celeste'?  True
#
# ¿variable numero == 15? True
# ¿variable numero == 12? False

# %% [markdown]
# # INSTRUCCION $if$

# %%
color = 'verde'

if (color == 'celeste'):
  print('La variable \'color\' es celeste')

# %%
if color == 'rojo':
   print('Ahora la variable \'color\' es rojo')

# %% [markdown]
# ### TAREA 1: Averiguar si una variable nota es *aprobatoria*

# %%
nota = 17.5
if (nota >=12.5):
  print("Felicitaciones. Has aprobado!")
# Out:
# Felicitaciones. Has aprobado!

# %% [markdown]
# ### TAREA 2: Averiguar si valor de una variable numero es *positivo*

# %% [markdown]
# # INSTRUCCION ***if/else***

# %%
color = "celeste"

if color == 'azul':
  print('Variable color es azul')
else:
  print('Variable color NO es azul')
# Out:
# Variable color NO es azul

# %% [markdown]
# ### TAREA 3: Averiguar si valor de una variable nota es *aprobatoria* o *desaprobatoria*

# %% [markdown]
# ### TAREA 4: Averiguar si valor de una variable numero es *par* o *impar*

# %%
nota=15
if (nota % 2 == 0):
  print(nota,"es par")
else:
  print(nota,"es impar")
# Out:
# 15 es impar

# %% [markdown]
# # INSTRUCCION ***if/else*** anidada

# %%
color = "violeta"

if color == 'azul':
  print('Variable color es azul')
else:
  if color == 'celeste':
    print('Variable color es celeste')
  else:
    print('Variable color NO es celeste')
# Out:
# Variable color NO es celeste

# %% [markdown]
# #### TAREA 5: Averiguar si pasa o no pasa el curso. Si no pasa, ver si puede ir a sustitutorio.

# %%
nota = 11.5
if nota>= 12.5:
  print("aprobaste")
else:
  if nota >= 11 and nota < 12.5:
    print("vas a susti")
  else:
    print("Sorry.")
# Out:
# vas a susti

# %%
color= 'amarillo'

if color == 'azul':
  print('Variable color es azul')
elif color == 'rojo':
  print('Variable color es rojo')
elif color == 'celeste':
  print("------------------")
  print('Variable color es celeste')
else:
  print('Variable color NO es azul, rojo ni celeste')
# Out:
# Variable color NO es azul, rojo ni celeste

# %% [markdown]
# ### TAREA 6: Pedir un numero entero mayor que 0 y menor que 8. De acuerdo a ello imprimir el dia de la semana correspondiente (Ej. 1 es Lunes, 2 es Martes, etc.). Usar una tupla para los dias de la semana.

# %%
dias = ("Lunes", "Martes", "Miercoles", "Jueves", "Viernes", "Sabado", "Domingo")
x = int(input("Numero"))

if x<0 or x >7:
  print("Error")
else:
  print(dias[x-1])
# Out:
# Numero2
# Martes

# %% [markdown]
# # OPERADORES LOGICOS: ***and***, ***or***, ***not***

# %% [markdown]
# # Expresiones logicas compuestas con ***and***

# %%
color = "azul"
numero = 16

print("¿variable color == 'celeste' and numero == 15 ?")
print(color == "celeste" and numero == 15)
# Out:
# ¿variable color == 'celeste' and numero == 15 ?
# False

# %%
print("¿variable color == 'azul' and numero == 16 ?")
print(color == "azul" and numero == 16)
# Out:
# ¿variable color == 'azul' and numero == 16 ?
# True

# %%
print("¿variable color == 'celeste' and numero == 12 ?")
print(color == "celeste" and numero == 12)
# Out:
# ¿variable color == 'celeste' and numero == 12 ?
# False

# %%
print("¿variable color == 'verde' and numero == 15 ?")
print(color == "verde" and numero == 15)
# Out:
# ¿variable color == 'verde' and numero == 15 ?
# False

# %%
print("¿variable color == 'verde' and numero == 12 ?")
print(color == "verde" and numero == 12)
# Out:
# ¿variable color == 'verde' and numero == 12 ?
# False

# %% [markdown]
# ### TAREA 7: Usar operador **and** para decidir si un alumno pasa el curso considerando nota y numero de inasistencias permitido.

# %% [markdown]
# # Expresiones logicas compuestas con ***or***

# %%
color, numero = "azul", 15
print("¿variable color == 'celeste' or numero == 15 ?")

print(color == "celeste" or numero == 15)
# Out:
# ¿variable color == 'celeste' or numero == 15 ?
# True

# %%
print("¿variable color == 'celeste' or numero == 12 ?")
print(color == "celeste" or numero == 12)
# Out:
# ¿variable color == 'celeste' or numero == 12 ?
# False

# %%
print("¿variable color == 'azul' or numero == 15 ?")
print(color == "azul" or numero == 15)
# Out:
# ¿variable color == 'azul' or numero == 15 ?
# True

# %%
print("¿variable color == 'verde' or numero == 12 ?")
print(color == "verde" or numero == 12)
# Out:
# ¿variable color == 'verde' or numero == 12 ?
# False

# %% [markdown]
# ### TAREA 8: Usar operador **or** para decidir si un alumno desaprueba el curso considerando nota y numero de inasistencias permitido.

# %% [markdown]
# # Expresiones logicas simples con ***not***

# %%
print("negacion de ¿variable color == 'rojo' ?")
print( not (color == "rojo"))
# Out:
# negacion de ¿variable color == 'rojo' ?
# True

# %% [markdown]
# # Expresiones logicas compuestas con ***not***

# %%
print("negacion de ¿variable color == 'celeste' and numero == 15 ?")
print( not (color == "celeste" and numero == 15) )
# Out:
# negacion de ¿variable color == 'celeste' and numero == 15 ?
# True

# %% [markdown]
# # TAREA 9: Usar operador **not** y operador **and** para decidir si un alumno desaprueba el curso considerando nota y numero de inasistencias permitido.

# %% [markdown]
# # TAREA 10: Usar operador **not** y operador **or** para decidir si un alumno aprueba el curso considerando nota y numero de inasistencias permitido.
