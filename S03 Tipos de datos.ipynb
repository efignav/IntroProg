# %% [markdown]
# ## Tipos de datos

# %% [markdown]
# Numericos

# %%
a = 3
dec = 11.287

print(a)
print(dec)
# Out:
# 3
# 11.287

# %% [markdown]
# Numeros complejos

# %%
4.5 + 3j
# Out:
# (4.5+3j)

# %%
print( type(a) )
print( type(dec) )
# Out:
# <class 'int'>
# <class 'float'>

# %% [markdown]
# Strings (cadenas de texto)

# %%
nom = "algo"
otro = 'otro dato'

# %%
print(type(nom) )
print(otro)
# Out:
# <class 'str'>
# otro dato

# %%
x1 = "2"
x2 = "3"
x3 = x1 + x2
print(x3)
print( int(x1) + int(x2) )
# Out:
# 23
# 5

# %% [markdown]
# Booleanos

# %%
verd = True
fa = False

print( type(verd))
print(fa)
# Out:
# <class 'bool'>
# False

# %% [markdown]
# Colecciones

# %%
Lista = [1, 2, 3]
T = (5, 78, 23)
di = {"xx": "sem", "z1": 25}
Lista2 = [[4,8,9], [2,4]]

# %%
type(di)
# Out:
# dict

# %%
a1 = "-"
a2 = "2"

# %%
# print(a1 + a2)

# %%
print(a1 * 30)
# Out:
# ------------------------------

# %% [markdown]
# Operadores aritmeticos

# %%
x = 7
y = 2

z = x / y
print(z)
# Out:
# 3.5

# %%
12832 % 17
# Out:
# 14

# %%
23178 % 17
# Out:
# 7

# %% [markdown]
# // division entera

# %%
z2 = x // y
print(z2)
# Out:
# 3

# %% [markdown]
# % modulo ( o resto, o residuo)

# %%
z3 = x % y

print(z3)
# Out:
# 1

# %%
117 % 23
# Out:
# 2

# %% [markdown]
# Operadores relacionales

# %% [markdown]
# ## ==

# %%
s = 10

p = 12

n1 = s == p

print(n1)
# Out:
# False

# %% [markdown]
# ## !=

# %%
n2 = s != p

print(n2)
# Out:
# True

# %% [markdown]
# Operadores de asignacion

# %% [markdown]
# +=

# %%
b1 = 5
b2 = 2

b1 += b2

print(b1)
# Out:
# 7

# %% [markdown]
# Operadores logicos

# %%
a=3
b=2
b *= a
b
# Out:
# 6

# %% [markdown]
# and

# %%
c1 = 7
c2 = 12

c3 = (c1 == c2) and (c1 < c2)
print(c3)

# %% [markdown]
# or

# %%
c1 = 7
c2 = 12

c3 = (c1 == c2) or (c1 < c2)

# %%
print(c3)
# Out:
# True

# %% [markdown]
# xor

# %%
c4 =  (4 == 4) ^ (9>3)

print(c4)
# Out:
# False

# %%
c5 =  (4 == 4) ^ (9 < 3)

print(c5)
# Out:
# True
