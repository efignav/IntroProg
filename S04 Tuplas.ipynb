# %% [markdown]
# Creacion de tuplas

# %%
frutas = ('manzana','pera', 'naranja','uva')
print(frutas)
# Out:
# ('manzana', 'pera', 'naranja', 'uva')

# %%
print(frutas[3])
# Out:
# uva

# %%
(s1, s2, s3, s4)= t

# %%
print(s3)
# Out:
# naranja

# %% [markdown]
# Acceso a un elemento

# %%
print(frutas[0])
# Out:
# manzana

# %%
print(frutas[1])
# Out:
# pera

# %%
print(frutas[2])
# Out:
# naranja

# %% [markdown]
# Se puede modificar una tupla?
# No. Las tuplas son inmutables.

# %%
# frutas[0] = 'banana'

# %% [markdown]
# # Unpack

# %%
(f1,f2,f3, f4)= frutas

# %%
print(f1)
# Out:
# manzana

# %%
print(f3)
# Out:
# naranja

# %% [markdown]
# Operaciones
# - len
# - +
# - in

# %% [markdown]
# **len**

# %%
len(frutas)
# Out:
# 4

# %% [markdown]
# **+**

# %%
frutas2 = ('mandarina', 'coco')

# %%
frutas3 = frutas + frutas2

# %%
print(frutas3)
# Out:
# ('manzana', 'pera', 'naranja', 'uva', 'mandarina', 'coco')

# %% [markdown]
# **in**

# %%
'uva' in frutas
# Out:
# True

# %%
'uva' in frutas2
# Out:
# False

# %% [markdown]
# METODOS
# - Count
# - Index

# %% [markdown]
# Count

# %%
tupla1 = (1, 2, 3, 2, 4, 2, 5, 6, 2, 9, 3)
print(tupla1)
# Out:
# (1, 2, 3, 2, 4, 2, 5, 6, 2, 9, 3)

# %%
tupla1.count(2)
# Out:
# 4

# %% [markdown]
# # Index

# %%
tupla1.index(2)
# Out:
# 1

# %%
frutas5 = ('manzana','pera','naranja','uva')

# %%
'Uva' in frutas5
# Out:
# False
