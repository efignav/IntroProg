# %% [markdown]
# ### Escritura de archivos de texto

# %%
from google.colab import drive
import os

drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/Colab Notebooks')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
miArchivo = open("archivo1.txt", "r")
lineasT = miArchivo.readlines()
miArchivo.close()
print(lineasT)
# Out:
# ['122\n', '34\n', '56\n', '12\n', '27\n', '67']
# 122
#
# 34

# %%
print( int( lineasT[0] ) + int( lineasT[-1] ))
# Out:
# 189

# %%
miArchivo = open("archivo2.txt", "r")
lineasT = miArchivo.readlines()
miArchivo.close()

print(lineasT)
# Out:
# ['45.3\n', '15.5\n', '27.2\n', '56.8\n', '12.7\n']

# %%
print( float( lineasT[0] ) + float( lineasT[-1] ) )
# Out:
# 189.0

# %%
suma = 0
for i in lineasT:
  print(i)
  suma += float(i)

print(suma)
# Out:
# 122
#
# 34
#
# 56
#
# 12
#
# 27
#
# 67
# 318.0

# %%
miArchivo = open("archivo3.txt", "r")
lineasT = miArchivo.readlines()

print(lineasT)
# Out:
# ['Aprendiendo python\n', 'Estudiando presencialmente\n', 'Arriba Peru!!!!\n']

# %% [markdown]
# Hacer un programa que genere el siguiente resultado:

# %% [markdown]
# Aprendiendo python, Estudiando presencialmente, Arriba Peru!!!!

# %%
x = lineasT[0]
texto=""
print(lineasT[0].strip()) + "," + lineasT[1].strip() +"," + lineasT[2].strip())
# Out:
#   File "<ipython-input-39-d2b21567047b>", line 3
#     print(lineasT[0].strip()) + "," + lineasT[1].strip() +"," + lineasT[2].strip())
#                                                                                   ^
# SyntaxError: unmatched ')'

# %%
miArchivo = open("archivo3.txt", "r")
print(miArchivo.read())
miArchivo.close()
# Out:
# Aprendiendo python
# Estudiando presencialmente
# Arriba Peru!!!!

# %% [markdown]
# Funcion

# %%
def leer_archivo(file):
    miarchivo = open(file, "r")
    lineas = miarchivo.readlines()

    miarchivo.close()

    return lineas

# %%
leer_archivo("archivo2.txt")
# Out:
# ['45.3\n', '15.5\n', '27.2\n', '56.8\n', '12.7\n']

# %%
miArchivo = open("archivo3.txt", "r")
print(miArchivo.read())
print(miArchivo.read())
print(miArchivo.read())
# Out:
# Aprendiendo python
# Estudiando presencialmente
# Arriba Peru!!!!

# %%
miArchivo = open("archivo3.txt", "r")
miArchivo.seek(12)
print("\n", miArchivo.read())
# Out:
#  python
# Estudiando presencialmente
# Arriba Peru!!!!
